# %%
import os.path
 
if not os.path.exists("../stylegan2-ada-pytorch"):
  # !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
  # !pip install ninja
 
 
if not os.path.exists("../stylegan2-ada-pytorch"):
  # !gdown --id 1-GMHbiz4c5YaiNReT1s249gWHYHWXM0G
  # %cd stylegan2-ada-pytorch/
 
#you can change the seed 0-20 means the seed is between 0 - 20 and it will generate 20 images
# !python generate.py --outdir=../out --seeds=0-20 --network=../network-snapshot-000400.pkl
 
import glob
from IPython.display import Image
from PIL import Image
import matplotlib.pyplot as plt
 
 
 
for path in glob.glob("../out/*.*"):
    plt.figure()
    plt.imshow(Image.open(path))
 
# %rm -r ../out
